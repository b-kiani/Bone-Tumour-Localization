# %% [markdown]
# # Stage-1 — MURA pretraining (abnormal vs normal)
# Trains an image-level abnormality classifier on MURA and exports `history.csv` and checkpoints.
#
# **Backbones:** Swin-T, ConvNeXt-T, EfficientNetV2-S (via `timm`).
#
# Adjust Windows paths in the config to your environment.

# %%
print('Open and run cells top-to-bottom. This notebook is a template.')

# %% [markdown]
# ## Recommended usage
# If you already have `mura.py`, call it from a notebook cell (Windows):

# %%
# Example (Windows): adapt paths
# !python mura.py ^
  --stage1_dir "C:\BTXRD - Copy\mura_stage1_final_224" ^
  --outdir "C:\BTXRD - Copy\paper_figs"
