# %% [markdown]
# # Stage-3 — YOLOv8 detection + FROC
# Template notebook for training/inference and FROC evaluation.
#
# Use your existing exported CSVs:
# - `froc_all_iou.csv`, `froc_all_iou_with_ci.csv`
# - per-IoU `froc_iou_*.csv` and `froc_iou_*.png`

# %%
import pandas as pd
from pathlib import Path

# %%
# Point to your exports
root = Path(r"C:\BTXRD - Copy")
froc = pd.read_csv(root/"stage3_eval_pub_fast3"/"froc_all_iou_with_ci.csv")
froc.head()
